# %%
import cv2
img =  cv2.imread('/Users/yamadatakuya/Desktop/dataknock_sample/9章/img/img01.jpg')
height, width = img.shape[:2]
print('画像幅:' + str(width))
print('画像高さ:' + str(height))
cv2.imshow('img', img)
cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-fe5851d4a4ae> in <module>
# ----> 1 import cv2
#       2 img =  cv2.imread('/Users/yamadatakuya/Desktop/dataknock_sample/9章/img/img01.jpg')
#       3 height, width = img.shape[:2]
#       4 print('画像幅:' + str(width))
#       5 print('画像高さ:' + str(height))
#
# ModuleNotFoundError: No module named 'cv2'
